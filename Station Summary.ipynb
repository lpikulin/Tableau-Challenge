# %%
import pandas as pd

# %%
filename="201909-citibike-tripdata.csv\\201909-citibike-tripdata.csv"
bikes_df=pd.read_csv(filename)

# %%
bikes_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           327  2019-09-01 00:00:01.9580  2019-09-01 00:05:29.3410
# 1          1145  2019-09-01 00:00:04.1430  2019-09-01 00:19:09.8360
# 2          1293  2019-09-01 00:00:07.3090  2019-09-01 00:21:40.7580
# 3          1753  2019-09-01 00:00:08.0640  2019-09-01 00:29:21.5040
# 4           613  2019-09-01 00:00:12.8510  2019-09-01 00:10:26.1850
#
#    start station id           start station name  start station latitude  \
# 0              3733           Avenue C & E 18 St               40.730563
# 1              3329         Degraw St & Smith St               40.682915
# 2              3168  Central Park West & W 85 St               40.784727
# 3              3299           E 98 St & Park Ave               40.788130
# 4               486           Broadway & W 29 St               40.746201
#
#    start station longitude  end station id             end station name  \
# ...

# %%
bikes_df.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  2.444900e+06      2.444900e+06            2.444900e+06
# mean   1.012112e+03      1.664439e+03            4.073733e+01
# std    9.710675e+03      1.483324e+03            3.021870e-02
# min    6.100000e+01      7.200000e+01            4.065540e+01
# 25%    3.920000e+02      3.790000e+02            4.071755e+01
# 50%    6.680000e+02      5.090000e+02            4.073705e+01
# 75%    1.156000e+03      3.296000e+03            4.075725e+01
# max    2.904620e+06      3.858000e+03            4.081439e+01
#
#        start station longitude  end station id  end station latitude  \
# count             2.444900e+06    2.444900e+06          2.444900e+06
# mean             -7.398215e+01    1.657267e+03          4.073696e+01
# std               2.010678e-02    1.483102e+03          3.013548e-02
# min              -7.402535e+01    7.200000e+01          4.065540e+01
# ...

# %%
start=['start station latitude','start station longitude','start station name']
start_df=bikes_df.groupby(by=start).count().reset_index()
start_df=start_df[['start station latitude','start station longitude','bikeid']]
start_df=start_df.rename(columns={'start station latitude':'latitude',
                                  'start station longitude':'longitude',
                                  'bikeid':'start_count'})
start_df.head()
# Out:
#     latitude  longitude  start_count
# 0  40.655400 -74.010628          359
# 1  40.657089 -74.008702          597
# 2  40.661063 -73.979453         3520
# 3  40.662706 -73.956912          534
# 4  40.663062 -73.953875          636

# %%
end=['end station latitude','end station longitude','end station name']
end_df=bikes_df.groupby(by=end).count().reset_index()
end_df=end_df[['end station latitude','end station longitude','end station name','bikeid']]
end_df=end_df.rename(columns={'end station latitude':'latitude',
                                'end station longitude':'longitude',
                                'end station name':'station',
                                'bikeid':'end_count'})
end_df.head()
# Out:
#     latitude  longitude                                        station  \
# 0  40.655400 -74.010628  39 St & 2 Ave - Citi Bike HQ at Industry City
# 1  40.657089 -74.008702  2 Ave & 36 St - Citi Bike HQ at Industry City
# 2  40.661063 -73.979453                West Drive & Prospect Park West
# 3  40.662706 -73.956912                      Sterling St & Bedford Ave
# 4  40.663062 -73.953875                       Rogers Ave & Sterling St
#
#    end_count
# 0        368
# 1        614
# 2       3555
# 3        529
# 4        642

# %%
merge_vars=['latitude','longitude']
station_df=pd.merge(start_df,end_df,how='outer',on=merge_vars)
station_df.head()
# Out:
#     latitude  longitude  start_count  \
# 0  40.655400 -74.010628        359.0
# 1  40.657089 -74.008702        597.0
# 2  40.661063 -73.979453       3520.0
# 3  40.662706 -73.956912        534.0
# 4  40.663062 -73.953875        636.0
#
#                                          station  end_count
# 0  39 St & 2 Ave - Citi Bike HQ at Industry City        368
# 1  2 Ave & 36 St - Citi Bike HQ at Industry City        614
# 2                West Drive & Prospect Park West       3555
# 3                      Sterling St & Bedford Ave        529
# 4                       Rogers Ave & Sterling St        642

# %%
station_df.to_csv('summary.csv')
